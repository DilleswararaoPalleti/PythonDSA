# %%
a={'hi','abc','temp',23}

# %%
type(a)
# Out:
# set

# %%
'k' in a
# Out:
# False

# %%
a.add("hello")

# %%
a
# Out:
# {23, 'abc', 'hello', 'hi', 'temp'}

# %%
a
# Out:
# {23, 'abc', 'hello', 'hi', 'temp'}

# %%
a.pop()
# Out:
# 'abc'

# %%
b={"jio",'fiber'}
a.update(b)

# %%
a
# Out:
# {23, 'fiber', 'hello', 'hi', 'jio', 'temp'}

# %%
a.remove(23)

# %%
a.remove(23)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 a.remove(23)
#
# KeyError: 23

# %%
a.discard(23)

# %%
del(b)

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
a
# Out:
# {'fiber', 'hello', 'hi', 'jio', 'temp'}
