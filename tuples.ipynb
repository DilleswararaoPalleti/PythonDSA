# %%
a=2,3
type(a)
# Out:
# tuple

# %%
print(a)
# Out:
# (2, 3)

# %%
print(id(a[0]),id(a[1]))
# Out:
# 140713778824136 140713778824168

# %%
#in Tuples slicing is same as like is list
#tuples are immutable

# %%
#deleting the tuple
del a

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined
