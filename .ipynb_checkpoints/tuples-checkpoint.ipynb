# %%
a=2,3
type(a)
# Out:
# tuple

# %%
print(a)
# Out:
# (2, 3)

# %%
print(id(a[0]),id(a[1]))
# Out:
# 140713778824136 140713778824168

# %%
#in Tuples slicing is same as like is list
#tuples are immutable

# %%
#deleting the tuple
k=1,2,3,4
del k

# %%
#repitation
e=a*3
e
# Out:
# (2, 3, 2, 3, 2, 3)

# %%
#concatination
a=(1,2,3,4)
b=(4,6)
c=a+b
c
# Out:
# (1, 2, 3, 4, 4, 6)

# %%
c=a,b
c[0][0]
# Out:
# 1

# %%
c
# Out:
# ((1, 2, 3, 4), (4, 6))
