# %%
d={"a":2,"b":3,56:10}
type(d)
# Out:
# dict

# %%
d
# Out:
# {'a': 2, 'b': 3, 56: 10}

# %%
d.copy()
# Out:
# {'a': 2, 'b': 3, 56: 10}

# %%
c=dict([(10,1),("Adarsh",5),(35,18)])

# %%
c
# Out:
# {10: 1, 'Adarsh': 5, 35: 18}

# %%
d=dict.fromkeys([1,2,5,6,7],90)

# %%
d
# Out:
# {1: 90, 2: 90, 5: 90, 6: 90, 7: 90}

# %%
#Access the data in dictionaries
aa={1:2,3:4,"list":[1,2,3,4],"dict":{1:2}}
a
# Out:
# {1: 2, 3: 4, 'list': [1, 2, 3, 4], 'dict': {1: 2}}

# %%
type(a['dict'])
# Out:
# dict

# %%
a.get(3)
# Out:
# 4

# %%
p=a.get("li")

# %%
a.keys()
# Out:
# dict_keys([1, 3, 'list', 'dict'])

# %%
a.values()
# Out:
# dict_values([2, 4, [1, 2, 3, 4], {1: 2}])

# %%
a.items()
# Out:
# dict_items([(1, 2), (3, 4), ('list', [1, 2, 3, 4]), ('dict', {1: 2})])

# %%
type(a)
# Out:
# dict

# %%
a={"k":3,1: 4,7:9}
a[1]
# Out:
# 4

# %%
a['t']=(1,2,3)

# %%
type(a['t'])
# Out:
# tuple

# %%
a['y']={1,2,3,4}

# %%
a
# Out:
# {'k': 3, 1: 4, 7: 9, 't': (1, 2, 3), 'y': {1, 2, 3, 4}}

# %%
type(a['y'])
# Out:
# set

# %%
aa
# Out:
# {1: 2, 3: 4, 'list': [1, 2, 3, 4], 'dict': {1: 2}}

# %%
b={1:5,3:9}

# %%
aa.update(b)

# %%
aa
# Out:
# {1: 5, 3: 9, 'list': [1, 2, 3, 4], 'dict': {1: 2}}

# %%
aa.pop('dict')
# Out:
# {1: 2}

# %%
aa
# Out:
# {1: 5, 3: 9, 'list': [1, 2, 3, 4]}

# %%
aa[2]=10

# %%
aa
# Out:
# {1: 5, 3: 9, 'list': [1, 2, 3, 4], 2: 10}

# %%
del aa[2]

# %%
aa
# Out:
# {1: 5, 3: 9, 'list': [1, 2, 3, 4]}

# %%
a.clear()

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
del a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 del a
#
# NameError: name 'a' is not defined
