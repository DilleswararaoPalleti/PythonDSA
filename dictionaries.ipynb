# %%
d={"a":2,"b":3,56:10}
type(d)
# Out:
# dict

# %%
d
# Out:
# {'a': 2, 'b': 3, 56: 10}

# %%
d.copy()
# Out:
# {'a': 2, 'b': 3, 56: 10}

# %%
c=dict([(10,1),("Adarsh",5),(35,18)])

# %%
c
# Out:
# {10: 1, 'Adarsh': 5, 35: 18}

# %%
d=dict.fromkeys([1,2,5,6,7],90)

# %%
d
# Out:
# {1: 90, 2: 90, 5: 90, 6: 90, 7: 90}
