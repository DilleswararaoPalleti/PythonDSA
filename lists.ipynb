# %%
li=[]
li=[1,2,3]

# %%
type(li)
# Out:
# list

# %%
li=[1,0.6,"thro"]

# %%
li[2]=6

# %%
li
# Out:
# [1, 0.6, 6]

# %%
##Slicing of a list
li[:2]
# Out:
# [1, 0.6]

# %%
li.insert(3,45)

# %%
li
# Out:
# [1, 0.6, 89, 45]

# %%
li.append(39)

# %%
li
# Out:
# [1, 0.6, 89, 45, 39]

# %%
li.append([3,4,5])

# %%
li
# Out:
# [1, 0.6, 89, 45, 39, [3, 4, 5]]

# %%
# add multiple elements
li.extend([2,3,4])

# %%
li
# Out:
# [1, 0.6, 89, 45, 39, [3, 4, 5], 2, 3, 4]

# %%
#remove the element from list
li.remove(1)

# %%
li
# Out:
# [0.6, 89, 45, 39, [3, 4, 5], 2, 3, 4]

# %%
li.pop()
# Out:
# 4

# %%
li
# Out:
# [0.6, 89, 45, 39, [3, 4, 5], 2, 3]

# %%
li.pop(4)
# Out:
# [3, 4, 5]

# %%
li
# Out:
# [0.6, 89, 45, 39, 2, 3]

# %%
len(li)
# Out:
# 6

# %%
 #problems on lists
li=[1,2,3,4,5,6]
for i in li:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(len(li)):
    print(li[i])
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in li[1:]:
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
#Negative Indexing
li[-1]
# Out:
# 6

# %%
#sequencing Indexing
li[1:3:1]
# Out:
# [2, 3]

# %%
li
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
li[-5:-1]
# Out:
# [2, 3, 4, 5]

# %%
li[-1]
# Out:
# 6

# %%
#lineseparated input on list
n=int(input())
li=[]
for i in range(n):
    ele=int(input())
    li.append(ele)
# Out:
#  5
#  1
#  2
#  3
#  4
#  5

# %%
li
# Out:
# [1, 2, 3, 4, 5]

# %%
#space seperated input
s=input()
# Out:
#  1,2,3,4,5

# %%
s
# Out:
# '1,2,3,4,5'

# %%
s_split=s.split(',')

# %%
li=[]
for i in s_split:
    li.append(int(i))

# %%
li
# Out:
# [1, 2, 3, 4, 5]

# %%
s=input()
# Out:
#  1  2  3  4  5

# %%
s=[int(x) for x in input().split(' ')]
# Out:
#  1 2 3 4 5

# %%
type(s)
# Out:
# list
