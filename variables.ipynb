# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ### Variables

# %%
a=20
b=59
a+b
# Out:
# 79

# %% [markdown]
# variables can be lowercase, uppercase, numbers, underscore also fine

# %% [markdown]
# you cant start variable name with numbers

# %% [markdown]
# ### assign different type of date to variable

# %%
a=10
a="Adarsh"
type(a)
# Out:
# str

# %% [markdown]
# ### Numbers

# %%
a1=23
a2=5.9
a3=5+4j
print(type(a3))
# Out:
# <class 'complex'>

# %%
print(id(a1))
# Out:
# 140736626247272

# %%
print(id(a1+1))
# Out:
# 140736626247304

# %%
a=256
b=256
c=256
d=256
print(id(a))
print(id(b))
print(id(c))
print(id(d))
# Out:
# 140722578350984
# 140722578350984
# 140722578350984
# 140722578350984

# %%
a=-5
b=-5
c=-5
d=-5
print(id(a))
print(id(b))
print(id(c))
print(id(d))
# Out:
# 140736626246376
# 140736626246376
# 140736626246376
# 140736626246376

# %%
#limits of numbers
#incase of java fixed storage of type of datatype but in python no fix storage

# %% [markdown]
# ### Arithmatic operators

# %%
10//3
# Out:
# 3

# %%
print(10**2)
10-3
# Out:
# 100
# 7

# %%
83/2
# Out:
# 41.5

# %%
2*3//4
# Out:
# 1

# %%
 #fah to celcius conversion
f=98.6
c=(f-32)*5/9
print(c)
ci=(f-32)*5//9
ci
# Out:
# 37.0
# 37.0

# %% [markdown]
# ### input

# %%
a=int(input("enter a"))
b=int(input("enter b"))
c=int(input("enter c"))
avg=(a+b+c)/3
avg
# Out:
# enter a 3
# enter b 3
# enter c 3
# 3.0
